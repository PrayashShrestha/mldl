# %% [markdown]
# # <span style="background:green; color:white; padding:10px;">String, Objects and List Objects</span>

# %% [markdown]
# #### 1. 1. Create the below pattern using nested for loop in Python.

# %%
def pattern(n):
      for i in range(0, n):
           for j in range(0, i + 1):
                print("* ", end="")
           print("")
      for i in range(n-1, 0 , -1):
          for j in range(1, i + 1):
               print("* ", end="")
          print("")
 
pattern(5)
# Out:
# *
# * *
# * * *
# * * * *
# * * * * *
# * * * *
# * * *
# * *
# *

# %% [markdown]
# #### 2. Write a Python program to reverse a word after accepting the input from the user.

# %%
def reverse(str):
    if(len(str) == 0):
        return str
    else:
        return reverse(str[1:])+str[0]
if __name__ =="__main__":
    inp = input("Input Word: ")
    print("Output: " + reverse(inp))
# Out:
# Input Word: ineuron
# Output: norueni
